# %%
import numpy as np
import math
import os
import pickle
import pandas as pd
import torch
import torch.nn as nn
import torch.utils
from scipy.stats import zscore
import torch.utils.data
from torchvision import datasets, transforms
from torch.autograd import Variable
import matplotlib.pyplot as plt

def _rmse (x, x_hat):
    x = x[1:]
    x_hat = x_hat[1:]
    return np.sqrt(np.mean(((x-x_hat)**2)))

# %% [markdown]
# ## Load Data Sets in Memory

# %%
path = 'Path to the Data'
with open(path+'train_resampled.pickle', 'rb') as handle:
    train_resampled = pickle.load(handle)
with open(path+'test_resampled.pickle', 'rb') as handle:
    test_resampled = pickle.load(handle)
with open(path+'dis_train.pickle', 'rb') as handle:
    dis_train = pickle.load(handle)
with open(path+'dis_test.pickle', 'rb') as handle:
    dis_test = pickle.load(handle)
with open(path+'Scalar.pickle', 'rb') as handle:
    Scalar = pickle.load(handle)
train_resampled = train_resampled[:13400]
dis_train = dis_train[:13400]
train_resampled = [train_resampled[idx].values[:-1] for idx in range(len(train_resampled))]
test_resampled = [test_resampled[idx].values[:-1] for idx in range(len(test_resampled))]

# %% [markdown]
# ## Variational Recurrent Neural Network (VRNN)

# %%
class VRNN(nn.Module):
    
    def __init__(self, x_dim, h_dim, z_dim, n_layers, bias = True ):
        
        super(VRNN, self).__init__()

        self.x_dim = x_dim
        self.h_dim = h_dim
        self.z_dim = z_dim
        self.n_layers = n_layers

        #feature-extracting transformations
        self.phi_x = nn.Sequential( nn.Linear(self.x_dim , self.h_dim), nn.Tanh(), 
                                   nn.Linear(self.h_dim, self.h_dim), nn.Tanh())
        self.phi_z = nn.Sequential( nn.Linear(self.z_dim, self.h_dim), nn.Tanh())

        #encoder
        self.enc = nn.Sequential( nn.Linear(self.h_dim + self.h_dim * self.n_layers , 
                                            self.h_dim), nn.Tanh(), nn.Linear(self.h_dim, self.h_dim), nn.Tanh())
        
        self.enc_mean = nn.Sequential( nn.Linear(self.h_dim, self.z_dim), nn.Tanh())
        self.enc_std = nn.Sequential( nn.Linear(self.h_dim, self.z_dim), nn.Sigmoid())

        #prior
        self.prior = nn.Sequential( nn.Linear(self.n_layers * self.h_dim, self.h_dim), nn.Tanh())
        self.prior_mean = nn.Sequential( nn.Linear(self.h_dim, self.z_dim), nn.Tanh())
        self.prior_std = nn.Sequential( nn.Linear(self.h_dim, self.z_dim), nn.Sigmoid())

        #decoder
        self.dec = nn.Sequential( nn.Linear(self.h_dim + self.h_dim * self.n_layers , self.h_dim), nn.Tanh(), 
                                 nn.Linear(self.h_dim, self.h_dim), nn.Tanh())
        self.dec_std = nn.Sequential( nn.Linear(self.h_dim, self.x_dim), nn.Sigmoid())
        self.dec_mean = nn.Sequential( nn.Linear( self.h_dim, self.x_dim ), nn.Tanh())

        #recurrence
        self.rnn = nn.GRU ( self.h_dim + self.h_dim + self.n_layers * self.h_dim, self.h_dim, 
                           self.n_layers, bias , batch_first = True )
        
    def encode (self, phi_x_t , h):
        phi_x_t = self._concatenate (phi_x_t , h)
        enc_t = self.enc(phi_x_t)
        enc_mean_t = self.enc_mean(enc_t)
        enc_std_t = self.enc_std(enc_t)
        return enc_mean_t , enc_std_t
        
    
    def decode (self, phi_z_t , h):
        phi_z_t = self._concatenate (phi_z_t , h)
        dec_t = self.dec(phi_z_t)
        dec_mean_t = self.dec_mean(dec_t)
        dec_std_t = self.dec_std(dec_t)
        return dec_mean_t , dec_std_t
        
    def forward(self, x):
        all_enc_mean, all_enc_std = [], []
        all_dec_mean, all_dec_std = [], []
        kld_loss = 0
        nll_loss = 0

        h = Variable(torch.zeros(self.n_layers, x.size(0), self.h_dim))
        
        for t in range(x.size(1)):
            
            phi_x_t = self.phi_x(x[:,t,:].float())
            #encoder
            enc_mean_t , enc_std_t = self.encode(phi_x_t , h)
            #prior
            prior_t = self.prior(h.reshape (h.shape[1] , n_layers * h_dim))
            prior_mean_t = self.prior_mean(prior_t)
            prior_std_t = self.prior_std(prior_t)
            #sampling and reparameterization
            z_t = self._reparameterized_sample(enc_mean_t, enc_std_t)
            phi_z_t = self.phi_z(z_t)
            #decoder
            dec_mean_t , dec_std_t = self.decode(phi_z_t , h)
            
            #recurrence
            temp = self._concatenate ( torch.cat ( [ phi_x_t , phi_z_t ] , 1) , h )
            _, h = self.rnn(temp.reshape(temp.shape[0] , 1 , temp.shape[1]))

            kld_loss += self._kld_gauss(enc_mean_t, enc_std_t.mul(0.5).exp_(), prior_mean_t, prior_std_t.mul(0.5).exp_())
            nll_loss += self._nll_gauss(dec_mean_t, dec_std_t, x[:,t,:])
                
            all_enc_std.append(enc_std_t)
            all_enc_mean.append(enc_mean_t)
            all_dec_mean.append(dec_mean_t)
            all_dec_std.append(dec_std_t)


        return kld_loss, nll_loss,(all_enc_mean, all_enc_std),(all_dec_mean, all_dec_std)
    
   
    def _reparameterized_sample(self, mean, logvar):
        """using std to sample"""
        std = logvar.mul(0.5).exp_()
        eps = torch.FloatTensor(std.size()).normal_()
        eps = Variable(eps)
        return eps.mul(std).add_(mean)


    def _kld_gauss(self, mean_1, std_1, mean_2, std_2):
        """Using std to compute KLD"""

        kld_element =  (2 * torch.log(std_2) - 2 * torch.log(std_1) +
            (std_1.pow(2) + (mean_1 - mean_2).pow(2)) /
            std_2.pow(2) - 1)
        return 0.5 * torch.sum(kld_element)

    def _nll_gauss(self, mean, logvar , x):
        return torch.sum( 0.5 * np.log (2 * np.pi) + 0.5 * logvar + (x-mean)**2 / (2 *  torch.exp(logvar)) )
    
    def _concatenate (self , a , b) :
        for i in range(len(b)):
            a = torch.cat([a , b[i]] , 1)
        return a

# %% [markdown]
# ## Configure the Hyper-Parameters and Model

# %%
#hyperparameters
x_dim = 7
h_dim = 50
z_dim = 2
n_layers =  2
n_epochs = 5
clip = 10
learning_rate = 1e-3
batch_size = 100
seed = 100
print_every = 10
save_every = 10
#manual seed
torch.manual_seed(seed)
#init model + optimizer + datasets
train_loader = torch.utils.data.DataLoader ( dataset = train_resampled ,  batch_size = 100 , shuffle= True)
test_loader = torch.utils.data.DataLoader (  dataset = test_resampled , shuffle= True)
model = VRNN(x_dim, h_dim, z_dim, n_layers)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ## Train and Test the Model

# %%
def train(epoch):
    train_loss = 0
    epoch_loss = np.zeros(int(len (train_resampled) / batch_size ))
    epoch_div = np.zeros(int(len (train_resampled) / batch_size))
    for batch_idx, (data) in enumerate(train_loader):
        
        data = Variable(data)
        #forward + backward + optimize
        optimizer.zero_grad()
        kld_loss, nll_loss, _, _ = model(data)
        epoch_loss [batch_idx] = nll_loss
        epoch_div [batch_idx] = kld_loss
        loss = kld_loss + nll_loss
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()
        #printing
        if batch_idx % print_every == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\t KLD Loss: {:.6f} \t NLL Loss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader),
                kld_loss.data / batch_size,
                nll_loss.data / batch_size))

            

        train_loss += loss.data
    print('====> Epoch: {} Average loss: {:.4f}'.format(
        epoch, train_loss / len(train_loader.dataset)))
    return epoch_loss, epoch_div
    
def test(epoch):
    """uses test data to evaluate 
    likelihood of the model"""
    mean_kld_loss, mean_nll_loss = 0, 0
    epoch_loss = np.zeros(len(test_resampled))
    epoch_div = np.zeros(len(test_resampled))
    for i, (data) in enumerate(test_loader):                                           
        
        data = Variable(data.reshape(1,47,7))
        kld_loss, nll_loss, _, _ = model(data)
        epoch_div [i] = kld_loss
        epoch_loss [i] = nll_loss
        mean_kld_loss += kld_loss.data
        mean_nll_loss += nll_loss.data

    mean_kld_loss /= len(test_loader.dataset)
    mean_nll_loss /= len(test_loader.dataset)

    print('====> Test set loss: KLD Loss = {:.4f}, NLL Loss = {:.4f} '.format(
        mean_kld_loss, mean_nll_loss))
    return epoch_loss, epoch_div

# %% [markdown]
# ## Run the Training and Validation/Testing

# %%
train_error = np.zeros([n_epochs , int(len (train_resampled) / batch_size ) ])
train_div = np.zeros([n_epochs , int(len (train_resampled) / batch_size ) ])
test_error , test_div  = np.zeros([n_epochs , len(test_resampled)]) , np.zeros([n_epochs , len(test_resampled)]) 
for epoch in range(1, n_epochs + 1):
    tr = train(epoch)
    train_error [epoch-1 , :] = tr [0]
    train_div [epoch-1 , :] = tr [1] 
    te = test(epoch)
    test_error [epoch-1 , :] = te [0]
    test_div [epoch-1 , :] = te [1]
# Out:
# Train Epoch: 1 [0/13400 (0%)]	 KLD Loss: 0.801358 	 NLL Loss: 474.860322
# Train Epoch: 1 [1000/13400 (7%)]	 KLD Loss: 0.310493 	 NLL Loss: 412.112253
# Train Epoch: 1 [2000/13400 (15%)]	 KLD Loss: 0.099474 	 NLL Loss: 364.397420
# Train Epoch: 1 [3000/13400 (22%)]	 KLD Loss: 0.094253 	 NLL Loss: 341.186902
# Train Epoch: 1 [4000/13400 (30%)]	 KLD Loss: 0.037586 	 NLL Loss: 326.992924
# Train Epoch: 1 [5000/13400 (37%)]	 KLD Loss: 0.011391 	 NLL Loss: 319.205941
# Train Epoch: 1 [6000/13400 (45%)]	 KLD Loss: 0.015711 	 NLL Loss: 314.993175
# Train Epoch: 1 [7000/13400 (52%)]	 KLD Loss: 0.010740 	 NLL Loss: 312.738187
# Train Epoch: 1 [8000/13400 (60%)]	 KLD Loss: 0.006648 	 NLL Loss: 311.420841
# Train Epoch: 1 [9000/13400 (67%)]	 KLD Loss: 0.003423 	 NLL Loss: 310.647297
# Train Epoch: 1 [10000/13400 (75%)]	 KLD Loss: 0.001504 	 NLL Loss: 309.760401
# Train Epoch: 1 [11000/13400 (82%)]	 KLD Loss: 0.011680 	 NLL Loss: 304.235460
# Train Epoch: 1 [12000/13400 (90%)]	 KLD Loss: 0.016274 	 NLL Loss: 303.912167
# Train Epoch: 1 [13000/13400 (97%)]	 KLD Loss: 0.005668 	 NLL Loss: 303.518479
# ====> Epoch: 1 Average loss: 331.9615
# ====> Test set loss: KLD Loss = 0.0741, NLL Loss = 303.4025
# Train Epoch: 2 [0/13400 (0%)]	 KLD Loss: 0.006057 	 NLL Loss: 303.403853
# Train Epoch: 2 [1000/13400 (7%)]	 KLD Loss: 0.007107 	 NLL Loss: 303.121443
# Train Epoch: 2 [2000/13400 (15%)]	 KLD Loss: 0.038166 	 NLL Loss: 302.999067
# Train Epoch: 2 [3000/13400 (22%)]	 KLD Loss: 0.005888 	 NLL Loss: 302.864399
# Train Epoch: 2 [4000/13400 (30%)]	 KLD Loss: 0.005638 	 NLL Loss: 302.836861
# Train Epoch: 2 [5000/13400 (37%)]	 KLD Loss: 0.006798 	 NLL Loss: 302.728132
# Train Epoch: 2 [6000/13400 (45%)]	 KLD Loss: 0.007139 	 NLL Loss: 302.706375
# Train Epoch: 2 [7000/13400 (52%)]	 KLD Loss: 0.003369 	 NLL Loss: 302.714848
# Train Epoch: 2 [8000/13400 (60%)]	 KLD Loss: 0.002473 	 NLL Loss: 302.692454
# Train Epoch: 2 [9000/13400 (67%)]	 KLD Loss: 0.001091 	 NLL Loss: 302.646512
# Train Epoch: 2 [10000/13400 (75%)]	 KLD Loss: 0.000995 	 NLL Loss: 302.704809
# Train Epoch: 2 [11000/13400 (82%)]	 KLD Loss: 0.000680 	 NLL Loss: 302.610080
# Train Epoch: 2 [12000/13400 (90%)]	 KLD Loss: 0.000563 	 NLL Loss: 302.609561
# Train Epoch: 2 [13000/13400 (97%)]	 KLD Loss: 0.000576 	 NLL Loss: 302.636537
# ====> Epoch: 2 Average loss: 302.8002
# ====> Test set loss: KLD Loss = 0.0458, NLL Loss = 302.5813
# Train Epoch: 3 [0/13400 (0%)]	 KLD Loss: 0.000550 	 NLL Loss: 302.579220
# Train Epoch: 3 [1000/13400 (7%)]	 KLD Loss: 0.000614 	 NLL Loss: 302.580528
# Train Epoch: 3 [2000/13400 (15%)]	 KLD Loss: 0.000465 	 NLL Loss: 302.601807
# Train Epoch: 3 [3000/13400 (22%)]	 KLD Loss: 0.000467 	 NLL Loss: 302.547030
# Train Epoch: 3 [4000/13400 (30%)]	 KLD Loss: 0.000446 	 NLL Loss: 302.546376
# Train Epoch: 3 [5000/13400 (37%)]	 KLD Loss: 0.000461 	 NLL Loss: 302.574316
# Train Epoch: 3 [6000/13400 (45%)]	 KLD Loss: 0.000444 	 NLL Loss: 302.518895
# Train Epoch: 3 [7000/13400 (52%)]	 KLD Loss: 0.000421 	 NLL Loss: 302.521308
# Train Epoch: 3 [8000/13400 (60%)]	 KLD Loss: 0.000462 	 NLL Loss: 302.545756
# Train Epoch: 3 [9000/13400 (67%)]	 KLD Loss: 0.000395 	 NLL Loss: 302.497441
# Train Epoch: 3 [10000/13400 (75%)]	 KLD Loss: 0.000389 	 NLL Loss: 302.500910
# Train Epoch: 3 [11000/13400 (82%)]	 KLD Loss: 0.000416 	 NLL Loss: 302.520458
# Train Epoch: 3 [12000/13400 (90%)]	 KLD Loss: 0.000401 	 NLL Loss: 302.481212
# Train Epoch: 3 [13000/13400 (97%)]	 KLD Loss: 0.000398 	 NLL Loss: 302.498229
# ====> Epoch: 3 Average loss: 302.5375
# ====> Test set loss: KLD Loss = 0.0426, NLL Loss = 302.5026
# Train Epoch: 4 [0/13400 (0%)]	 KLD Loss: 0.000387 	 NLL Loss: 302.501535
# Train Epoch: 4 [1000/13400 (7%)]	 KLD Loss: 0.000327 	 NLL Loss: 302.469893
# Train Epoch: 4 [2000/13400 (15%)]	 KLD Loss: 0.000353 	 NLL Loss: 302.477547
# Train Epoch: 4 [3000/13400 (22%)]	 KLD Loss: 0.000316 	 NLL Loss: 302.479233
# Train Epoch: 4 [4000/13400 (30%)]	 KLD Loss: 0.000330 	 NLL Loss: 302.459163
# Train Epoch: 4 [5000/13400 (37%)]	 KLD Loss: 0.000331 	 NLL Loss: 302.466287
# Train Epoch: 4 [6000/13400 (45%)]	 KLD Loss: 0.000290 	 NLL Loss: 302.460966
# Train Epoch: 4 [7000/13400 (52%)]	 KLD Loss: 0.000309 	 NLL Loss: 302.451246
# Train Epoch: 4 [8000/13400 (60%)]	 KLD Loss: 0.000275 	 NLL Loss: 302.460518
# Train Epoch: 4 [9000/13400 (67%)]	 KLD Loss: 0.000266 	 NLL Loss: 302.443305
# Train Epoch: 4 [10000/13400 (75%)]	 KLD Loss: 0.000565 	 NLL Loss: 302.445144
# Train Epoch: 4 [11000/13400 (82%)]	 KLD Loss: 0.000503 	 NLL Loss: 302.448925
# Train Epoch: 4 [12000/13400 (90%)]	 KLD Loss: 0.000272 	 NLL Loss: 302.452594
# Train Epoch: 4 [13000/13400 (97%)]	 KLD Loss: 0.000723 	 NLL Loss: 302.413530
# ====> Epoch: 4 Average loss: 302.4590
# ====> Test set loss: KLD Loss = 0.0413, NLL Loss = 302.4203
# Train Epoch: 5 [0/13400 (0%)]	 KLD Loss: 0.000600 	 NLL Loss: 302.419019
# Train Epoch: 5 [1000/13400 (7%)]	 KLD Loss: 0.000259 	 NLL Loss: 302.449705
# Train Epoch: 5 [2000/13400 (15%)]	 KLD Loss: 0.000336 	 NLL Loss: 302.412179
# Train Epoch: 5 [3000/13400 (22%)]	 KLD Loss: 0.000250 	 NLL Loss: 302.421222
# Train Epoch: 5 [4000/13400 (30%)]	 KLD Loss: 0.000196 	 NLL Loss: 302.427932
# Train Epoch: 5 [5000/13400 (37%)]	 KLD Loss: 0.000214 	 NLL Loss: 302.413647
# Train Epoch: 5 [6000/13400 (45%)]	 KLD Loss: 0.000194 	 NLL Loss: 302.424112
# Train Epoch: 5 [7000/13400 (52%)]	 KLD Loss: 0.000214 	 NLL Loss: 302.410429
# Train Epoch: 5 [8000/13400 (60%)]	 KLD Loss: 0.009087 	 NLL Loss: 302.412514
# Train Epoch: 5 [9000/13400 (67%)]	 KLD Loss: 0.013616 	 NLL Loss: 302.399320
# Train Epoch: 5 [10000/13400 (75%)]	 KLD Loss: 0.002215 	 NLL Loss: 302.409450
# Train Epoch: 5 [11000/13400 (82%)]	 KLD Loss: 0.008487 	 NLL Loss: 302.402193
# Train Epoch: 5 [12000/13400 (90%)]	 KLD Loss: 0.000314 	 NLL Loss: 302.398307
# Train Epoch: 5 [13000/13400 (97%)]	 KLD Loss: 0.000641 	 NLL Loss: 302.419910
# ====> Epoch: 5 Average loss: 302.4182
# ====> Test set loss: KLD Loss = 0.0293, NLL Loss = 302.3904

# %% [markdown]
# ## Save the Training Data, Model, Error

# %%
with open(path +'_train_error.pickle', 'wb') as handle:
    pickle.dump(train_error, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(path +'_test_error.pickle', 'wb') as handle:
    pickle.dump(test_error, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(path +'_train_div.pickle', 'wb') as handle:
    pickle.dump(train_div, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(path +'_test_div.pickle', 'wb') as handle:
    pickle.dump(test_div, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(path +'_Model.pickle', 'wb') as handle:
    pickle.dump(model, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(path +'_train_loader.pickle', 'wb') as handle:
    pickle.dump(train_loader, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(path +'_test_loader.pickle', 'wb') as handle:
    pickle.dump(test_loader, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## RMSE on Test Data Set

# %%
path = 'Path to the Data'
with open(path, 'rb') as handle:
    test_resampled = pickle.load(handle)
test_resampled = [test_resampled[idx].values for idx in range(len(test_resampled))]
result =  [ model (torch.tensor (test_resampled[idx]).reshape(1,48,7)) for idx in range(len(test_resampled)) ]
torch.manual_seed(seed)
dist = [ torch.distributions.normal.Normal (result[idx][3][0][0] , result[idx][3][1][0].mul(0.5).exp_()) for idx in range(len(result))]
recon_x = [ dist[idx].sample((10000,)).mean(0) for idx in range(len(dist)) ]
error = [ _rmse(test_resampled[idx][-1] , np.array(recon_x[idx][-1])) for idx in range(len(test_resampled)) ]
print ('Average RMSE for Test Data is: '+str(np.mean(error)))
print ('Variance of RMSE for Test Data is: '+str(np.std(error)))
# Out:
# Average RMSE for Test Data is: 0.011525418915417399
# Variance of RMSE for Test Data is: 0.003458234483058563
